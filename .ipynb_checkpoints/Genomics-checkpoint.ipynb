# %% [markdown]
# # Downloading_sequences

# %%
import os
from Bio import SeqIO
from Bio import Entrez

def download_genome_gff (accession_ids, outputfolder="."):
    Entrez.email = "20ilmb03@uohyd.ac.in"

    for accession_id in accession_ids:
        filename = os.path.join(output_folder, f"{accession_id}.fasta")

        if not os.path.isfile(filename):
            stream = Entrez.efetch(db="nucleotide", id=accession_id, rettype="fasta", retmode="text")
            with open(filename, "w") as record:
                record.write(stream.read())
            stream.close()
            print(f"Downloaded {accession_id} to {filename}")
        else:
            print(f"{accession_id} already exists.")

with open("/home/gokul/Desktop/Genomics_Basics/sequences/id.txt", "r") as file:
    accession_ids = [line.strip() for line in file.readlines()]

output_folder = "/home/gokul/Desktop/Genomics_Basics/sequences"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
download_genome_gff(accession_ids, output_folder)
# Out:
# NC_075037.1 already exists.
# NC_021858.1 already exists.
# NC_023423.1 already exists.
# NC_037057.1 already exists.
# NC_044945.1 already exists.
# NC_037656.1 already exists.
# NC_044939.1 already exists.
# NC_001824.1 already exists.
# NC_006273.2 already exists.
# NC_002331.1 already exists.
# NC_001460.1 already exists.
# NC_010537.1 already exists.
# NC_076691.1 already exists.
# NC_055060.1 already exists.
# NC_004718.3 already exists.
# NC_004162.2 already exists.
# NC_012532.1 already exists.
# NC_001633.1 already exists.
# NC_003555.1 already exists.
# NC_075114.1 already exists.
# NC_001802.1 already exists.
# NC_001498.1 already exists.
# NC_055061.1 already exists.
# NC_007409.1 already exists.
# NC_001538.1 already exists.
# NC_076691.1 already exists.
# NC_018519.1 already exists.
# NC_014821.1 already exists.
# NC_076918.1 already exists.
# NC_017970.1 already exists.

# %% [markdown]
# # Creating a data frame.

# %%
import pandas as pd

data = pd.DataFrame({'Accession ID': accession_ids})
print (data)
# Out:
#    Accession ID
# 0   NC_075037.1
# 1   NC_021858.1
# 2   NC_023423.1
# 3   NC_037057.1
# 4   NC_044945.1
# 5   NC_037656.1
# 6   NC_044939.1
# 7   NC_001824.1
# 8   NC_006273.2
# 9   NC_002331.1
# 10  NC_001460.1
# 11  NC_010537.1
# 12  NC_076691.1
# 13  NC_055060.1
# 14  NC_004718.3
# 15  NC_004162.2
# 16  NC_012532.1
# 17  NC_001633.1
# 18  NC_003555.1
# 19  NC_075114.1
# 20  NC_001802.1
# 21  NC_001498.1
# 22  NC_055061.1
# 23  NC_007409.1
# 24  NC_001538.1
# 25  NC_076691.1
# 26  NC_018519.1
# 27  NC_014821.1
# 28  NC_076918.1
# 29  NC_017970.1
# /tmp/ipykernel_4135/2414385354.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Genome_size

# %%
fasta_files = [str(accession) + ".fasta" for accession in accession_ids]

def calculate_genome_size(fasta_file):
    total_length = 0
    sequence_length = 0

    with open(fasta_file, "r") as file:
        for line in file:
            line = line.strip()
            if line.startswith(">"):
                continue
            else:
                sequence_length += len(line)
    sequence_length

    return sequence_length
genome_sizes_list = []

for fasta_file_path in fasta_files:
    genome_size = calculate_genome_size(f"/home/gokul/Desktop/Genomics_Basics/sequences/{fasta_file_path}")
    genome_sizes_list.append(genome_size)
data['Genome_size'] = genome_sizes_list
print(data)
#genome_size_dict = dict(zip(accession_ids, genome_sizes_list))
#print (genome_size_dict)
# Out:
#    Accession ID  Genome_size
# 0   NC_075037.1      1016844
# 1   NC_021858.1      1908524
# 2   NC_023423.1       610033
# 3   NC_037057.1       181035
# 4   NC_044945.1       191058
# 5   NC_037656.1       127879
# 6   NC_044939.1       199721
# 7   NC_001824.1       102653
# 8   NC_006273.2       235646
# 9   NC_002331.1       178733
# 10  NC_001460.1        34125
# 11  NC_010537.1        41172
# 12  NC_076691.1        18371
# 13  NC_055060.1        18266
# 14  NC_004718.3        29751
# 15  NC_004162.2        11826
# 16  NC_012532.1        10794
# 17  NC_001633.1         4009
# 18  NC_003555.1         6277
# 19  NC_075114.1         3248
# 20  NC_001802.1         9181
# 21  NC_001498.1        15894
# 22  NC_055061.1        17253
# 23  NC_007409.1        62730
# 24  NC_001538.1         5153
# 25  NC_076691.1        18371
# 26  NC_018519.1        17798
# 27  NC_014821.1         9311
# 28  NC_076918.1         6632
# 29  NC_017970.1        10731

# %% [markdown]
# # GC Percentage

# %%
def calculate_GC_percentage(fasta_file):
    sequence_length = 0
    G_C=0
    with open(fasta_file, "r") as file:
        for line in file:
            line = line.strip()
            if line.startswith(">"):
                continue
            else:
                for i in line:
                    if i == 'G'or i == 'C':
                        G_C+=1
                    else:
                        continue
                sequence_length += len(line)
    G_C_perc = (G_C/sequence_length)*100

    return G_C_perc
G_C_perc_list = []

for fasta_file_path in fasta_files:
    G_C_percentage = calculate_GC_percentage(f"/home/gokul/Desktop/Genomics_Basics/sequences/{fasta_file_path}")
    G_C_perc_list.append(G_C_percentage)
data['GC_percentage'] = G_C_perc_list
print(data)
# Out:
#    Accession ID  Genome_size  GC_percentage
# 0   NC_075037.1      1016844      24.715492
# 1   NC_021858.1      1908524      63.663962
# 2   NC_023423.1       610033      35.798391
# 3   NC_037057.1       181035      52.726268
# 4   NC_044945.1       191058      38.252258
# 5   NC_037656.1       127879      31.279569
# 6   NC_044939.1       199721      45.845454
# 7   NC_001824.1       102653      29.070753
# 8   NC_006273.2       235646      57.482410
# 9   NC_002331.1       178733      40.678554
# 10  NC_001460.1        34125      46.523077
# 11  NC_010537.1        41172      34.644904
# 12  NC_076691.1        18371      51.075064
# 13  NC_055060.1        18266      54.620607
# 14  NC_004718.3        29751      40.761655
# 15  NC_004162.2        11826      50.042280
# 16  NC_012532.1        10794      50.935705
# 17  NC_001633.1         4009      46.270890
# 18  NC_003555.1         6277      50.039828
# 19  NC_075114.1         3248      48.275862
# 20  NC_001802.1         9181      42.119595
# 21  NC_001498.1        15894      47.426702
# 22  NC_055061.1        17253      54.471686
# 23  NC_007409.1        62730      41.225889
# 24  NC_001538.1         5153      39.530371
# 25  NC_076691.1        18371      51.075064
# 26  NC_018519.1        17798      45.595011
# 27  NC_014821.1         9311      42.433681
# 28  NC_076918.1         6632      52.080820
# 29  NC_017970.1        10731      40.928152

# %% [markdown]
# # Parsing GFF3

# %%
import pandas as pd

with open("/home/gokul/Desktop/Genomics_Basics/sequences/id.txt", "r") as file:
    accession_ids = [line.strip() for line in file.readlines()]
gff_files = [str(accession) + ".gff" for accession in accession_ids]

def parse_gff(gff_file_list):
    gff_dict = {}
    for file_path in gff_file_list:
        seqid_list = []
        source_list = []
        feature_type_list = []
        start_list = []
        end_list = []
        score_list = []
        strand_list = []
        phase_list = []
        attributes_list = []
        
        with open(f"/home/gokul/Desktop/Genomics_Basics/sequences/{file_path}", "r") as file:
            for line in file:
                line = line.strip()
                
                if line.startswith('#'):
                    continue
                else:
                    fields = line.split('\t')
                    if len(fields) >= 9:
                        seqid_list.append(fields[0])
                        source_list.append(fields[1])
                        feature_type_list.append(fields[2])
                        start_list.append(int(fields[3]))
                        end_list.append(int(fields[4]))
                        score_list.append(fields[5])
                        strand_list.append(fields[6])
                        phase_list.append(fields[7])
                        attributes_list.append(fields[8])
            gff_dict[f"{file_path}_df"] =  pd.DataFrame({'seqid': seqid_list,
                                               'source': source_list,
                                               'feature_type': feature_type_list,
                                               'start': start_list,
                                               'end': end_list,
                                               'score': score_list,
                                               'strand': strand_list,
                                               'phase': phase_list,
                                               'attributes': attributes_list})
        
    return gff_dict
gff_dict = parse_gff(gff_files)
print(gff_dict)
# Out:
# {'NC_075037.1.gff_df':             seqid  source feature_type    start      end score strand phase  \
# 0     NC_075037.1  RefSeq       region        1  1016844     .      +     .
# 1     NC_075037.1  RefSeq         gene      357      439     .      -     .
# 2     NC_075037.1  RefSeq         tRNA      357      439     .      -     .
# 3     NC_075037.1  RefSeq         exon      357      439     .      -     .
# 4     NC_075037.1  RefSeq         gene      980     1345     .      -     .
# ...           ...     ...          ...      ...      ...   ...    ...   ...
# 1957  NC_075037.1  RefSeq         gene  1015385  1015939     .      +     .
# 1958  NC_075037.1  RefSeq          CDS  1015385  1015939     .      +     0
# 1959  NC_075037.1  RefSeq         gene  1016543  1016625     .      +     .
# 1960  NC_075037.1  RefSeq         tRNA  1016543  1016625     .      +     .
# 1961  NC_075037.1  RefSeq         exon  1016543  1016625     .      +     .
#
#                                              attributes
# 0     ID=NC_075037.1:1..1016844;Dbxref=taxon:1247379...
# 1     ID=gene-QJ854_gt001;Dbxref=GeneID:80515667;Nam...
# 2     ID=rna-QJ854_gt001;Parent=gene-QJ854_gt001;Dbx...
# 3     ID=exon-QJ854_gt001-1;Parent=rna-QJ854_gt001;D...
# 4     ID=gene-QJ854_gp970;Dbxref=GeneID:80515668;Nam...
# ...                                                 ...
# 1957  ID=gene-QJ854_gp001;Dbxref=GeneID:80516640;Nam...
# 1958  ID=cds-YP_010780016.1;Parent=gene-QJ854_gp001;...
# 1959  ID=gene-QJ854_gt005;Dbxref=GeneID:80516641;Nam...
# 1960  ID=rna-QJ854_gt005;Parent=gene-QJ854_gt005;Dbx...
# 1961  ID=exon-QJ854_gt005-1;Parent=rna-QJ854_gt005;D...
#
# [1962 rows x 9 columns], 'NC_021858.1.gff_df':             seqid  source feature_type    start      end score strand phase  \
# 0     NC_021858.1  RefSeq       region        1  1908524     .      +     .
# 1     NC_021858.1  RefSeq         gene      885     1782     .      +     .
# 2     NC_021858.1  RefSeq          CDS      932     1711     .      +     0
# 3     NC_021858.1  RefSeq         gene     1787     3283     .      -     .
# 4     NC_021858.1  RefSeq          CDS     1836     3263     .      -     0
# ...           ...     ...          ...      ...      ...   ...    ...   ...
# 3062  NC_021858.1  RefSeq         gene  1907237  1907668     .      +     .
# 3063  NC_021858.1  RefSeq      lnc_RNA  1907237  1907668     .      +     .
# 3064  NC_021858.1  RefSeq         exon  1907237  1907668     .      +     .
# 3065  NC_021858.1  RefSeq         gene  1907520  1908291     .      -     .
# 3066  NC_021858.1  RefSeq          CDS  1907620  1908291     .      -     0
#
#                                              attributes
# 0     ID=NC_021858.1:1..1908524;Dbxref=taxon:1349409...
# 1     ID=gene-pdul_cds_1;Dbxref=GeneID:16512180;Name...
# 2     ID=cds-YP_008318537.1;Parent=gene-pdul_cds_1;D...
# 3     ID=gene-pdul_cds_2;Dbxref=GeneID:16512199;Name...
# 4     ID=cds-YP_008318538.2;Parent=gene-pdul_cds_2;D...
# ...                                                 ...
# 3062  ID=gene-pdul_ncRNA_268;Dbxref=GeneID:34568059;...
# 3063  ID=rna-pdul_ncRNA_268;Parent=gene-pdul_ncRNA_2...
# 3064  ID=exon-pdul_ncRNA_268-1;Parent=rna-pdul_ncRNA...
# 3065  ID=gene-pdul_cds_1071;Dbxref=GeneID:16512394;N...
# 3066  ID=cds-YP_008320023.2;Parent=gene-pdul_cds_107...
#
# [3067 rows x 9 columns], 'NC_023423.1.gff_df':             seqid  source     feature_type   start     end score strand phase  \
# 0     NC_023423.1  RefSeq           region       1  610033     .      +     .
# 1     NC_023423.1  RefSeq        stem_loop      24      55     .      +     .
# 2     NC_023423.1  RefSeq             gene      66     734     .      -     .
# 3     NC_023423.1  RefSeq              CDS      66     734     .      -     0
# 4     NC_023423.1  RefSeq  inverted_repeat     912    1895     .      +     .
# ...           ...     ...              ...     ...     ...   ...    ...   ...
# 2190  NC_023423.1  RefSeq        stem_loop  609346  609377     .      +     .
# 2191  NC_023423.1  RefSeq        stem_loop  609555  609587     .      +     .
# 2192  NC_023423.1  RefSeq        stem_loop  609636  609667     .      +     .
# 2193  NC_023423.1  RefSeq        stem_loop  609835  609866     .      +     .
# 2194  NC_023423.1  RefSeq        stem_loop  609915  609946     .      +     .
#
#                                              attributes
# 0     ID=NC_023423.1:1..610033;Dbxref=taxon:1450746;...
# 1     ID=id-NC_023423.1:24..55;Note=palindromic poly...
# 2     ID=gene-pv_1;Dbxref=GeneID:18266496;Name=pv_1;...
# 3     ID=cds-YP_009000903.1;Parent=gene-pv_1;Dbxref=...
# 4     ID=id-NC_023423.1:912..1895;gbkey=repeat_regio...
# ...                                                 ...
# 2190  ID=id-NC_023423.1:609346..609377;Note=palindro...
# 2191  ID=id-NC_023423.1:609555..609587;Note=palindro...
# 2192  ID=id-NC_023423.1:609636..609667;Note=palindro...
# 2193  ID=id-NC_023423.1:609835..609866;Note=palindro...
# 2194  ID=id-NC_023423.1:609915..609946;Note=palindro...
#
# [2195 rows x 9 columns], 'NC_037057.1.gff_df':            seqid  source feature_type   start     end score strand phase  \
# 0    NC_037057.1  RefSeq       region       1  181035     .      +     .
# 1    NC_037057.1  RefSeq         gene     265     453     .      +     .
# 2    NC_037057.1  RefSeq          CDS     265     453     .      +     0
# 3    NC_037057.1  RefSeq         gene     408    1205     .      -     .
# 4    NC_037057.1  RefSeq          CDS     408    1205     .      -     0
# ..           ...     ...          ...     ...     ...   ...    ...   ...
# 456  NC_037057.1  RefSeq          CDS  179826  180137     .      +     0
# 457  NC_037057.1  RefSeq         gene  180139  180354     .      -     .
# 458  NC_037057.1  RefSeq          CDS  180139  180354     .      -     0
# 459  NC_037057.1  RefSeq         gene  180389  180658     .      -     .
# 460  NC_037057.1  RefSeq          CDS  180389  180658     .      -     0
#
#                                             attributes
# 0    ID=NC_037057.1:1..181035;Dbxref=taxon:2079134;...
# 1    ID=gene-C5Y57_gp001;Dbxref=GeneID:35996974;Nam...
# 2    ID=cds-YP_009465718.1;Parent=gene-C5Y57_gp001;...
# 3    ID=gene-C5Y57_gp002;Dbxref=GeneID:35996804;Nam...
# 4    ID=cds-YP_009465719.1;Parent=gene-C5Y57_gp002;...
# ..                                                 ...
# 456  ID=cds-YP_009465942.1;Parent=gene-C5Y57_gp173;...
# 457  ID=gene-C5Y57_gp172;Dbxref=GeneID:35997029;Nam...
# 458  ID=cds-YP_009465943.1;Parent=gene-C5Y57_gp172;...
# 459  ID=gene-C5Y57_gp171;Dbxref=GeneID:35997030;Nam...
# 460  ID=cds-YP_009465944.1;Parent=gene-C5Y57_gp171;...
#
# [461 rows x 9 columns], 'NC_044945.1.gff_df':            seqid  source feature_type   start     end score strand phase  \
# 0    NC_044945.1  RefSeq       region       1  191058     .      +     .
# 1    NC_044945.1  RefSeq         gene     252    1322     .      -     .
# 2    NC_044945.1  RefSeq          CDS     252    1322     .      -     0
# 3    NC_044945.1  RefSeq         gene    1558    2628     .      -     .
# 4    NC_044945.1  RefSeq          CDS    1558    2628     .      -     0
# ..           ...     ...          ...     ...     ...   ...    ...   ...
# 332  NC_044945.1  RefSeq          CDS  187837  188214     .      +     0
# 333  NC_044945.1  RefSeq         gene  188314  189387     .      +     .
# 334  NC_044945.1  RefSeq          CDS  188314  189387     .      +     0
# 335  NC_044945.1  RefSeq         gene  189509  190582     .      +     .
# 336  NC_044945.1  RefSeq          CDS  189509  190582     .      +     0
#
#                                             attributes
# 0    ID=NC_044945.1:1..191058;Dbxref=taxon:10497;co...
# 1    ID=gene-F8211_gp001;Dbxref=GeneID:41901698;Nam...
# 2    ID=cds-YP_009702725.1;Parent=gene-F8211_gp001;...
# 3    ID=gene-F8211_gp002;Dbxref=GeneID:41901531;Nam...
# 4    ID=cds-YP_009702726.1;Parent=gene-F8211_gp002;...
# ..                                                 ...
# 332  ID=cds-YP_009702890.1;Parent=gene-F8211_gp166;...
# 333  ID=gene-F8211_gp167;Dbxref=GeneID:41901696;Nam...
# 334  ID=cds-YP_009702891.1;Parent=gene-F8211_gp167;...
# 335  ID=gene-F8211_gp168;Dbxref=GeneID:41901697;Nam...
# 336  ID=cds-YP_009702892.1;Parent=gene-F8211_gp168;...
#
# [337 rows x 9 columns], 'NC_037656.1.gff_df':            seqid  source   feature_type   start     end score strand phase  \
# 0    NC_037656.1  RefSeq         region       1  127879     .      +     .
# 1    NC_037656.1  RefSeq  repeat_region       1    2546     .      +     .
# 2    NC_037656.1  RefSeq           gene     127     990     .      -     .
# 3    NC_037656.1  RefSeq            CDS     127     990     .      -     0
# 4    NC_037656.1  RefSeq           gene    1372    2226     .      -     .
# ..           ...     ...            ...     ...     ...   ...    ...   ...
# 262  NC_037656.1  RefSeq  repeat_region  125334  127879     .      -     .
# 263  NC_037656.1  RefSeq           gene  125654  126508     .      +     .
# 264  NC_037656.1  RefSeq            CDS  125654  126508     .      +     0
# 265  NC_037656.1  RefSeq           gene  126890  127753     .      +     .
# 266  NC_037656.1  RefSeq            CDS  126890  127753     .      +     0
#
#                                             attributes
# 0    ID=NC_037656.1:1..127879;Dbxref=taxon:1416741;...
# 1    ID=id-NC_037656.1:1..2546;Note=terminal invert...
# 2    ID=gene-DP163_gp001;Dbxref=GeneID:36841130;Nam...
# 3    ID=cds-YP_009480539.1;Parent=gene-DP163_gp001;...
# 4    ID=gene-DP163_gp002;Dbxref=GeneID:36840999;Nam...
# ..                                                 ...
# 262  ID=id-NC_037656.1:125334..127879;Note=terminal...
# 263  ID=gene-DP163_gp131;Dbxref=GeneID:36841128;Nam...
# 264  ID=cds-YP_009480669.1;Parent=gene-DP163_gp131;...
# 265  ID=gene-DP163_gp132;Dbxref=GeneID:36841129;Nam...
# 266  ID=cds-YP_009480670.1;Parent=gene-DP163_gp132;...
#
# [267 rows x 9 columns], 'NC_044939.1.gff_df':            seqid  source feature_type   start     end score strand phase  \
# 0    NC_044939.1  RefSeq       region       1  199721     .      +     .
# 1    NC_044939.1  RefSeq         gene       1    3261     .      +     .
# 2    NC_044939.1  RefSeq          CDS       1    3261     .      +     0
# 3    NC_044939.1  RefSeq         gene    3456    4235     .      -     .
# 4    NC_044939.1  RefSeq          CDS    3456    4235     .      -     0
# ..           ...     ...          ...     ...     ...   ...    ...   ...
# 384  NC_044939.1  RefSeq          CDS  197723  197938     .      -     0
# 385  NC_044939.1  RefSeq         gene  198144  198962     .      -     .
# 386  NC_044939.1  RefSeq          CDS  198144  198962     .      -     0
# 387  NC_044939.1  RefSeq         gene  199161  199565     .      -     .
# 388  NC_044939.1  RefSeq          CDS  199161  199565     .      -     0
#
#                                             attributes
# 0    ID=NC_044939.1:1..199721;Dbxref=taxon:1246651;...
# 1    ID=gene-F8204_gp001;Dbxref=GeneID:41900988;Nam...
# 2    ID=cds-YP_009701657.1;Parent=gene-F8204_gp001;...
# 3    ID=gene-F8204_gp002;Dbxref=GeneID:41900795;Nam...
# 4    ID=cds-YP_009701658.1;Parent=gene-F8204_gp002;...
# ..                                                 ...
# 384  ID=cds-YP_009702185.1;Parent=gene-F8204_gp192;...
# 385  ID=gene-F8204_gp193;Dbxref=GeneID:41900986;Nam...
# 386  ID=cds-YP_009702186.1;Parent=gene-F8204_gp193;...
# 387  ID=gene-F8204_gp194;Dbxref=GeneID:41900987;Nam...
# 388  ID=cds-YP_009702187.1;Parent=gene-F8204_gp194;...
#
# [389 rows x 9 columns], 'NC_001824.1.gff_df':            seqid  source feature_type   start     end score strand phase  \
# 0    NC_001824.1  RefSeq       region       1  102653     .      +     .
# 1    NC_001824.1  RefSeq         gene     263     622     .      +     .
# 2    NC_001824.1  RefSeq          CDS     263     622     .      +     0
# 3    NC_001824.1  RefSeq         gene     619    1365     .      -     .
# 4    NC_001824.1  RefSeq          CDS     619    1365     .      -     0
# ..           ...     ...          ...     ...     ...   ...    ...   ...
# 217  NC_001824.1  RefSeq          CDS   99160   99876     .      -     0
# 218  NC_001824.1  RefSeq         gene   99948  100349     .      +     .
# 219  NC_001824.1  RefSeq          CDS   99948  100349     .      +     0
# 220  NC_001824.1  RefSeq         gene  100468  102651     .      +     .
# 221  NC_001824.1  RefSeq          CDS  100468  102651     .      +     0
#
#                                             attributes
# 0    ID=NC_001824.1:1..102653;Dbxref=taxon:36363;cl...
# 1    ID=gene-LCDV1gp001;Dbxref=GeneID:1497289;Name=...
# 2    ID=cds-NP_078614.1;Parent=gene-LCDV1gp001;Dbxr...
# 3    ID=gene-LCDV1gp002;Dbxref=GeneID:1497290;Name=...
# 4    ID=cds-NP_078615.1;Parent=gene-LCDV1gp002;Dbxr...
# ..                                                 ...
# 217  ID=cds-NP_078768.1;Parent=gene-LCDV1gp108;Dbxr...
# 218  ID=gene-LCDV1gp109;Dbxref=GeneID:1497396;Name=...
# 219  ID=cds-NP_078769.1;Parent=gene-LCDV1gp109;Dbxr...
# 220  ID=gene-LCDV1gp110;Dbxref=GeneID:1497397;Name=...
# 221  ID=cds-NP_078770.1;Parent=gene-LCDV1gp110;Dbxr...
#
# [222 rows x 9 columns], 'NC_006273.2.gff_df':            seqid  source      feature_type   start     end score strand phase  \
# 0    NC_006273.2  RefSeq            region       1  235646     .      +     .
# 1    NC_006273.2  RefSeq   inverted_repeat       1    1324     .      +     .
# 2    NC_006273.2  RefSeq     repeat_region       1     578     .      +     .
# 3    NC_006273.2  RefSeq              gene    1324    2386     .      +     .
# 4    NC_006273.2  RefSeq              mRNA    1356    2386     .      +     .
# ..           ...     ...               ...     ...     ...   ...    ...   ...
# 508  NC_006273.2  RefSeq              gene  232393  234759     .      -     .
# 509  NC_006273.2  RefSeq               CDS  232393  234759     .      -     0
# 510  NC_006273.2  RefSeq   inverted_repeat  233109  235646     .      +     .
# 511  NC_006273.2  RefSeq     repeat_region  235068  235646     .      +     .
# 512  NC_006273.2  RefSeq  sequence_feature  235646  235646     .      +     .
#
#                                             attributes
# 0    ID=NC_006273.2:1..235646;Dbxref=taxon:10359;ac...
# 1    ID=id-NC_006273.2:1..1324;Note=TRL;gbkey=repea...
# 2    ID=id-NC_006273.2:1..578;Note='a' sequence;gbk...
# 3    ID=gene-HHV5wtgp001;Dbxref=GeneID:3077430;Name...
# 4    ID=rna-HHV5wtgp001;Parent=gene-HHV5wtgp001;Dbx...
# ..                                                 ...
# 508  ID=gene-HHV5wtgp165;Dbxref=GeneID:3077523;Name...
# 509  ID=cds-YP_081619.1;Parent=gene-HHV5wtgp165;Dbx...
# 510  ID=id-NC_006273.2:233109..235646;Note=TRS;gbke...
# 511  ID=id-NC_006273.2:235068..235646;Note='a' sequ...
# 512  ID=id-NC_006273.2:235646..235646;Note=unpaired...
#
# [513 rows x 9 columns], 'NC_002331.1.gff_df':            seqid  source feature_type   start     end score strand phase  \
# 0    NC_002331.1  RefSeq       region       1  178733     .      +     .
# 1    NC_002331.1  RefSeq         gene       1     747     .      +     .
# 2    NC_002331.1  RefSeq          CDS       1     747     .      +     0
# 3    NC_002331.1  RefSeq         gene     795    1490     .      -     .
# 4    NC_002331.1  RefSeq          CDS     795    1490     .      -     0
# ..           ...     ...          ...     ...     ...   ...    ...   ...
# 358  NC_002331.1  RefSeq          CDS  176847  177440     .      +     0
# 359  NC_002331.1  RefSeq         gene  177406  178383     .      +     .
# 360  NC_002331.1  RefSeq          CDS  177406  178383     .      +     0
# 361  NC_002331.1  RefSeq         gene  178383  178715     .      +     .
# 362  NC_002331.1  RefSeq          CDS  178383  178715     .      +     0
#
#                                             attributes
# 0    ID=NC_002331.1:1..178733;Dbxref=taxon:51677;Is...
# 1    ID=gene-XecnGVgp001;Dbxref=GeneID:1442235;Name...
# 2    ID=cds-NP_059149.1;Parent=gene-XecnGVgp001;Dbx...
# 3    ID=gene-XecnGVgp002;Dbxref=GeneID:1442236;Name...
# 4    ID=cds-NP_059150.1;Parent=gene-XecnGVgp002;Dbx...
# ..                                                 ...
# 358  ID=cds-NP_059327.1;Parent=gene-XecnGVgp179;Dbx...
# 359  ID=gene-XecnGVgp180;Dbxref=GeneID:1442414;Name...
# 360  ID=cds-NP_059328.1;Parent=gene-XecnGVgp180;Dbx...
# 361  ID=gene-XecnGVgp181;Dbxref=GeneID:1442415;Name...
# 362  ID=cds-NP_059329.1;Parent=gene-XecnGVgp181;Dbx...
#
# [363 rows x 9 columns], 'NC_001460.1.gff_df':            seqid  source           feature_type  start    end score strand  \
# 0    NC_001460.1  RefSeq                 region      1  34125     .      +
# 1    NC_001460.1  RefSeq          repeat_region      1    164     .      +
# 2    NC_001460.1  RefSeq                   gene    415   1442     .      +
# 3    NC_001460.1  RefSeq                    CDS    503   1070     .      +
# 4    NC_001460.1  RefSeq                    CDS   1145   1377     .      +
# ..           ...     ...                    ...    ...    ...   ...    ...
# 115  NC_001460.1  RefSeq                 intron  32996  33780     .      -
# 116  NC_001460.1  RefSeq                 intron  33369  33780     .      -
# 117  NC_001460.1  RefSeq  polyA_signal_sequence  31166  31171     .      -
# 118  NC_001460.1  RefSeq               TATA_box  33838  33843     .      -
# 119  NC_001460.1  RefSeq          repeat_region  33963  34125     .      +
#
#     phase                                         attributes
# 0       .  ID=NC_001460.1:1..34125;Dbxref=taxon:129875;ac...
# 1       .  ID=id-NC_001460.1:1..164;gbkey=repeat_region;r...
# 2       .  ID=gene-HAdVAgp01;Dbxref=GeneID:1460853;Name=E...
# 3       0  ID=cds-NP_040910.2;Parent=gene-HAdVAgp01;Dbxre...
# 4       2  ID=cds-NP_040910.2;Parent=gene-HAdVAgp01;Dbxre...
# ..    ...                                                ...
# 115     .  ID=id-HAdVAgp16-4;Parent=gene-HAdVAgp16;Dbxref...
# 116     .  ID=id-HAdVAgp16-5;Parent=gene-HAdVAgp16;Dbxref...
# 117     .  ID=id-HAdVAgp16-6;Parent=gene-HAdVAgp16;Dbxref...
# 118     .  ID=id-HAdVAgp16-7;Parent=gene-HAdVAgp16;Dbxref...
# 119     .  ID=id-NC_001460.1:33963..34125;gbkey=repeat_re...
#
# [120 rows x 9 columns], 'NC_010537.1.gff_df':            seqid  source feature_type  start    end score strand phase  \
# 0    NC_010537.1  RefSeq       region      1  41172     .      +     .
# 1    NC_010537.1  RefSeq         gene    397    645     .      -     .
# 2    NC_010537.1  RefSeq          CDS    397    645     .      -     0
# 3    NC_010537.1  RefSeq         gene    649   1017     .      -     .
# 4    NC_010537.1  RefSeq          CDS    649   1017     .      -     0
# ..           ...     ...          ...    ...    ...   ...    ...   ...
# 142  NC_010537.1  RefSeq          CDS  40050  40253     .      -     0
# 143  NC_010537.1  RefSeq         gene  40293  40466     .      -     .
# 144  NC_010537.1  RefSeq          CDS  40293  40466     .      -     0
# 145  NC_010537.1  RefSeq         gene  40501  40725     .      -     .
# 146  NC_010537.1  RefSeq          CDS  40501  40725     .      -     0
#
#                                             attributes
# 0    ID=NC_010537.1:1..41172;Dbxref=taxon:512792;gb...
# 1    ID=gene-AFV9_gp01;Dbxref=GeneID:6186726;Name=A...
# 2    ID=cds-YP_001798519.1;Parent=gene-AFV9_gp01;Db...
# 3    ID=gene-AFV9_gp02;Dbxref=GeneID:6186715;Name=A...
# 4    ID=cds-YP_001798520.1;Parent=gene-AFV9_gp02;Db...
# ..                                                 ...
# 142  ID=cds-YP_001798589.1;Parent=gene-AFV9_gp71;Db...
# 143  ID=gene-AFV9_gp72;Dbxref=GeneID:6186709;Name=A...
# 144  ID=cds-YP_001798590.1;Parent=gene-AFV9_gp72;Db...
# 145  ID=gene-AFV9_gp73;Dbxref=GeneID:6186708;Name=A...
# 146  ID=cds-YP_001798591.1;Parent=gene-AFV9_gp73;Db...
#
# [147 rows x 9 columns], 'NC_076691.1.gff_df':          seqid  source feature_type  start    end score strand phase  \
# 0  NC_076691.1  RefSeq       region      1  18371     .      +     .
# 1  NC_076691.1  RefSeq         gene    753  16787     .      +     .
# 2  NC_076691.1  RefSeq          CDS    753  16787     .      +     0
#
#                                           attributes
# 0  ID=NC_076691.1:1..18371;Dbxref=taxon:2599957;c...
# 1  ID=gene-QKQ65_gp1;Dbxref=GeneID:80538181;Name=...
# 2  ID=cds-YP_010799752.1;Parent=gene-QKQ65_gp1;Db...  , 'NC_055060.1.gff_df':           seqid  source feature_type  start    end score strand phase  \
# 0   NC_055060.1  RefSeq       region      1  18266     .      +     .
# 1   NC_055060.1  RefSeq         gene    264    443     .      -     .
# 2   NC_055060.1  RefSeq          CDS    264    443     .      -     0
# 3   NC_055060.1  RefSeq         gene    444    680     .      -     .
# 4   NC_055060.1  RefSeq          CDS    444    680     .      -     0
# ..          ...     ...          ...    ...    ...   ...    ...   ...
# 71  NC_055060.1  RefSeq          CDS  16771  17556     .      +     0
# 72  NC_055060.1  RefSeq         gene  17553  17888     .      +     .
# 73  NC_055060.1  RefSeq          CDS  17553  17888     .      +     0
# 74  NC_055060.1  RefSeq         gene  17878  18054     .      +     .
# 75  NC_055060.1  RefSeq          CDS  17878  18054     .      +     0
#
#                                            attributes
# 0   ID=NC_055060.1:1..18266;Dbxref=taxon:2500797;c...
# 1   ID=gene-KMD61_gp01;Dbxref=GeneID:65073133;Name...
# 2   ID=cds-YP_010084061.1;Parent=gene-KMD61_gp01;D...
# 3   ID=gene-KMD61_gp02;Dbxref=GeneID:65073097;Name...
# 4   ID=cds-YP_010084062.1;Parent=gene-KMD61_gp02;D...
# ..                                                ...
# 71  ID=cds-YP_010084094.1;Parent=gene-KMD61_gp09;D...
# 72  ID=gene-KMD61_gp08;Dbxref=GeneID:65073131;Name...
# 73  ID=cds-YP_010084095.1;Parent=gene-KMD61_gp08;D...
# 74  ID=gene-KMD61_gp07;Dbxref=GeneID:65073132;Name...
# 75  ID=cds-YP_010084096.1;Parent=gene-KMD61_gp07;D...
#
# [76 rows x 9 columns], 'NC_004718.3.gff_df':           seqid  source                  feature_type  start    end score  \
# 0   NC_004718.3  RefSeq                        region      1  29751     .
# 1   NC_004718.3  RefSeq                five_prime_UTR      1    264     .
# 2   NC_004718.3  RefSeq                          gene    265  21485     .
# 3   NC_004718.3  RefSeq                           CDS    265  13392     .
# 4   NC_004718.3  RefSeq                           CDS  13392  21485     .
# 5   NC_004718.3  RefSeq  mature_protein_region_of_CDS    265    804     .
# 6   NC_004718.3  RefSeq  mature_protein_region_of_CDS    805   2718     .
# 7   NC_004718.3  RefSeq  mature_protein_region_of_CDS   2719   8484     .
# 8   NC_004718.3  RefSeq  mature_protein_region_of_CDS   8485   9984     .
# 9   NC_004718.3  RefSeq  mature_protein_region_of_CDS   9985  10902     .
# 10  NC_004718.3  RefSeq  mature_protein_region_of_CDS  10903  11772     .
# 11  NC_004718.3  RefSeq  mature_protein_region_of_CDS  11773  12021     .
# 12  NC_004718.3  RefSeq  mature_protein_region_of_CDS  12022  12615     .
# 13  NC_004718.3  RefSeq  mature_protein_region_of_CDS  12616  12954     .
# 14  NC_004718.3  RefSeq  mature_protein_region_of_CDS  12955  13371     .
# 15  NC_004718.3  RefSeq  mature_protein_region_of_CDS  13372  13392     .
# 16  NC_004718.3  RefSeq  mature_protein_region_of_CDS  13392  13394     .
# 17  NC_004718.3  RefSeq  mature_protein_region_of_CDS  16167  17969     .
# 18  NC_004718.3  RefSeq  mature_protein_region_of_CDS  17970  19550     .
# 19  NC_004718.3  RefSeq  mature_protein_region_of_CDS  19551  20588     .
# 20  NC_004718.3  RefSeq  mature_protein_region_of_CDS  20589  21482     .
# 21  NC_004718.3  RefSeq                           CDS    265  13413     .
# 22  NC_004718.3  RefSeq  mature_protein_region_of_CDS    265    804     .
# 23  NC_004718.3  RefSeq  mature_protein_region_of_CDS    805   2718     .
# 24  NC_004718.3  RefSeq  mature_protein_region_of_CDS   2719   8484     .
# 25  NC_004718.3  RefSeq  mature_protein_region_of_CDS   8485   9984     .
# 26  NC_004718.3  RefSeq  mature_protein_region_of_CDS   9985  10902     .
# 27  NC_004718.3  RefSeq  mature_protein_region_of_CDS  10903  11772     .
# 28  NC_004718.3  RefSeq  mature_protein_region_of_CDS  11773  12021     .
# 29  NC_004718.3  RefSeq  mature_protein_region_of_CDS  12022  12615     .
# 30  NC_004718.3  RefSeq  mature_protein_region_of_CDS  12616  12954     .
# 31  NC_004718.3  RefSeq  mature_protein_region_of_CDS  12955  13371     .
# 32  NC_004718.3  RefSeq  mature_protein_region_of_CDS  13372  13410     .
# 33  NC_004718.3  RefSeq                          gene  21492  25259     .
# 34  NC_004718.3  RefSeq                           CDS  21492  25259     .
# 35  NC_004718.3  RefSeq                          gene  25268  26092     .
# 36  NC_004718.3  RefSeq                           CDS  25268  26092     .
# 37  NC_004718.3  RefSeq                          gene  25689  26153     .
# 38  NC_004718.3  RefSeq                           CDS  25689  26153     .
# 39  NC_004718.3  RefSeq                          gene  26117  26347     .
# 40  NC_004718.3  RefSeq                           CDS  26117  26347     .
# 41  NC_004718.3  RefSeq                          gene  26398  27063     .
# 42  NC_004718.3  RefSeq                           CDS  26398  27063     .
# 43  NC_004718.3  RefSeq                          gene  26913  27265     .
# 44  NC_004718.3  RefSeq                           CDS  27074  27265     .
# 45  NC_004718.3  RefSeq                          gene  27273  27641     .
# 46  NC_004718.3  RefSeq                           CDS  27273  27641     .
# 47  NC_004718.3  RefSeq                          gene  27638  27772     .
# 48  NC_004718.3  RefSeq                           CDS  27638  27772     .
# 49  NC_004718.3  RefSeq                          gene  27779  27898     .
# 50  NC_004718.3  RefSeq                           CDS  27779  27898     .
# 51  NC_004718.3  RefSeq                          gene  27864  28118     .
# 52  NC_004718.3  RefSeq                           CDS  27864  28118     .
# 53  NC_004718.3  RefSeq                          gene  28120  29388     .
# 54  NC_004718.3  RefSeq                           CDS  28120  29388     .
# 55  NC_004718.3  RefSeq                           CDS  28583  28795     .
# 56  NC_004718.3  RefSeq                          gene  28130  28426     .
# 57  NC_004718.3  RefSeq                           CDS  28130  28426     .
# 58  NC_004718.3  RefSeq               three_prime_UTR  28796  29751     .
#
#    strand phase                                         attributes
# 0       +     .  ID=NC_004718.3:1..29751;Dbxref=taxon:227984;co...
# 1       +     .               ID=id-NC_004718.3:1..264;gbkey=5'UTR
# 2       +     .  ID=gene-sarsp1;Dbxref=GeneID:1489680;Name=ORF1...
# 3       +     0  ID=cds-NP_828849.7;Parent=gene-sarsp1;Dbxref=G...
# 4       +     0  ID=cds-NP_828849.7;Parent=gene-sarsp1;Dbxref=G...
# 5       +     .  ID=id-NP_828849.7:1..180;Parent=cds-NP_828849....
# 6       +     .  ID=id-NP_828849.7:181..818;Parent=cds-NP_82884...
# 7       +     .  ID=id-NP_828849.7:819..2740;Parent=cds-NP_8288...
# 8       +     .  ID=id-NP_828849.7:2741..3240;Parent=cds-NP_828...
# 9       +     .  ID=id-NP_828849.7:3241..3546;Parent=cds-NP_828...
# 10      +     .  ID=id-NP_828849.7:3547..3836;Parent=cds-NP_828...
# 11      +     .  ID=id-NP_828849.7:3837..3919;Parent=cds-NP_828...
# 12      +     .  ID=id-NP_828849.7:3920..4117;Parent=cds-NP_828...
# 13      +     .  ID=id-NP_828849.7:4118..4230;Parent=cds-NP_828...
# 14      +     .  ID=id-NP_828849.7:4231..4369;Parent=cds-NP_828...
# 15      +     .  ID=id-NP_828849.7:4370..4377;Parent=cds-NP_828...
# 16      +     .  ID=id-NP_828849.7:4370..4377;Parent=cds-NP_828...
# 17      +     .  ID=id-NP_828849.7:5302..5902;Parent=cds-NP_828...
# 18      +     .  ID=id-NP_828849.7:5903..6429;Parent=cds-NP_828...
# 19      +     .  ID=id-NP_828849.7:6430..6775;Parent=cds-NP_828...
# 20      +     .  ID=id-NP_828849.7:6776..7073;Parent=cds-NP_828...
# 21      +     0  ID=cds-YP_009944365.1;Parent=gene-sarsp1;Dbxre...
# 22      +     .  ID=id-YP_009944365.1:1..180;Parent=cds-YP_0099...
# 23      +     .  ID=id-YP_009944365.1:181..818;Parent=cds-YP_00...
# 24      +     .  ID=id-YP_009944365.1:819..2740;Parent=cds-YP_0...
# 25      +     .  ID=id-YP_009944365.1:2741..3240;Parent=cds-YP_...
# 26      +     .  ID=id-YP_009944365.1:3241..3546;Parent=cds-YP_...
# 27      +     .  ID=id-YP_009944365.1:3547..3836;Parent=cds-YP_...
# 28      +     .  ID=id-YP_009944365.1:3837..3919;Parent=cds-YP_...
# 29      +     .  ID=id-YP_009944365.1:3920..4117;Parent=cds-YP_...
# 30      +     .  ID=id-YP_009944365.1:4118..4230;Parent=cds-YP_...
# 31      +     .  ID=id-YP_009944365.1:4231..4369;Parent=cds-YP_...
# 32      +     .  ID=id-YP_009944365.1:4370..4382;Parent=cds-YP_...
# 33      +     .  ID=gene-sars2;Dbxref=GeneID:1489668;Name=S;gbk...
# 34      +     0  ID=cds-YP_009825051.1;Parent=gene-sars2;Dbxref...
# 35      +     .  ID=gene-sars3a;Dbxref=GeneID:1489669;Name=ORF3...
# 36      +     0  ID=cds-YP_009825052.1;Parent=gene-sars3a;Dbxre...
# 37      +     .  ID=gene-sars3b;Dbxref=GeneID:1489670;Name=ORF3...
# 38      +     0  ID=cds-YP_009825053.1;Parent=gene-sars3b;Dbxre...
# 39      +     .  ID=gene-sars4;Dbxref=GeneID:1489671;Name=E;gbk...
# 40      +     0  ID=cds-YP_009825054.1;Parent=gene-sars4;Dbxref...
# 41      +     .  ID=gene-sars5;Dbxref=GeneID:1489672;Name=M;gbk...
# 42      +     0  ID=cds-YP_009825055.1;Parent=gene-sars5;Dbxref...
# 43      +     .  ID=gene-sars6;Dbxref=GeneID:1489673;Name=ORF6;...
# 44      +     0  ID=cds-YP_009825056.1;Parent=gene-sars6;Dbxref...
# 45      +     .  ID=gene-sars7a;Dbxref=GeneID:1489674;Name=ORF7...
# 46      +     0  ID=cds-YP_009825057.1;Parent=gene-sars7a;Dbxre...
# 47      +     .  ID=gene-sars7b;Dbxref=GeneID:1489675;Name=ORF7...
# 48      +     0  ID=cds-YP_009825058.1;Parent=gene-sars7b;Dbxre...
# 49      +     .  ID=gene-sars8a;Dbxref=GeneID:1489676;Name=ORF8...
# 50      +     0  ID=cds-YP_009825059.1;Parent=gene-sars8a;Dbxre...
# 51      +     .  ID=gene-sars8b;Dbxref=GeneID:1489677;Name=ORF8...
# 52      +     0  ID=cds-YP_009825060.1;Parent=gene-sars8b;Dbxre...
# 53      +     .  ID=gene-sars9a;Dbxref=GeneID:1489678;Name=N;gb...
# 54      +     0  ID=cds-YP_009825061.1;Parent=gene-sars9a;Dbxre...
# 55      +     0  ID=cds-YP_009825063.1;Parent=gene-sars9a;Dbxre...
# 56      +     .  ID=gene-sars9b;Dbxref=GeneID:1489679;Name=sars...
# 57      +     0  ID=cds-YP_009825062.1;Parent=gene-sars9b;Dbxre...
# 58      +     .         ID=id-NC_004718.3:28796..29751;gbkey=3'UTR  , 'NC_004162.2.gff_df':          seqid  source feature_type  start    end score strand phase  \
# 0  NC_004162.2  RefSeq       region      1  11826     .      +     .
# 1  NC_004162.2  RefSeq         gene     77   7501     .      +     .
# 2  NC_004162.2  RefSeq          CDS     77   7501     .      +     0
# 3  NC_004162.2  RefSeq         gene   7567  11313     .      +     .
# 4  NC_004162.2  RefSeq          CDS   7567  11313     .      +     0
#
#                                           attributes
# 0  ID=NC_004162.2:1..11826;Dbxref=taxon:37124;gbk...
# 1  ID=gene-CHIKVgp1;Dbxref=GeneID:956309;Name=CHI...
# 2  ID=cds-NP_690588.1;Parent=gene-CHIKVgp1;Dbxref...
# 3  ID=gene-CHIKVgp2;Dbxref=GeneID:956308;Name=CHI...
# 4  ID=cds-NP_690589.2;Parent=gene-CHIKVgp2;Dbxref...  , 'NC_012532.1.gff_df':           seqid  source                  feature_type  start    end score  \
# 0   NC_012532.1  RefSeq                        region      1  10794     .
# 1   NC_012532.1  RefSeq                five_prime_UTR      1    106     .
# 2   NC_012532.1  RefSeq                          gene    107  10366     .
# 3   NC_012532.1  RefSeq                           CDS    107  10366     .
# 4   NC_012532.1  RefSeq  mature_protein_region_of_CDS    107    472     .
# 5   NC_012532.1  RefSeq  mature_protein_region_of_CDS    107    418     .
# 6   NC_012532.1  RefSeq  mature_protein_region_of_CDS    473    976     .
# 7   NC_012532.1  RefSeq  mature_protein_region_of_CDS    473    751     .
# 8   NC_012532.1  RefSeq  mature_protein_region_of_CDS    752    976     .
# 9   NC_012532.1  RefSeq  mature_protein_region_of_CDS    977   2476     .
# 10  NC_012532.1  RefSeq  mature_protein_region_of_CDS   2477   3532     .
# 11  NC_012532.1  RefSeq  mature_protein_region_of_CDS   3533   4210     .
# 12  NC_012532.1  RefSeq  mature_protein_region_of_CDS   4211   4600     .
# 13  NC_012532.1  RefSeq  mature_protein_region_of_CDS   4601   6451     .
# 14  NC_012532.1  RefSeq  mature_protein_region_of_CDS   6452   6832     .
# 15  NC_012532.1  RefSeq  mature_protein_region_of_CDS   6833   6901     .
# 16  NC_012532.1  RefSeq  mature_protein_region_of_CDS   6902   7654     .
# 17  NC_012532.1  RefSeq  mature_protein_region_of_CDS   7655  10363     .
# 18  NC_012532.1  RefSeq               three_prime_UTR  10367  10794     .
#
#    strand phase                                         attributes
# 0       +     .  ID=NC_012532.1:1..10794;Dbxref=taxon:64320;cou...
# 1       +     .               ID=id-NC_012532.1:1..106;gbkey=5'UTR
# 2       +     .  ID=gene-ZIKV_gp1;Dbxref=GeneID:7751225;Name=PO...
# 3       +     0  ID=cds-YP_002790881.1;Parent=gene-ZIKV_gp1;Dbx...
# 4       +     .  ID=id-YP_002790881.1:1..122;Parent=cds-YP_0027...
# 5       +     .  ID=id-YP_002790881.1:1..104;Parent=cds-YP_0027...
# 6       +     .  ID=id-YP_002790881.1:123..290;Parent=cds-YP_00...
# 7       +     .  ID=id-YP_002790881.1:123..215;Parent=cds-YP_00...
# 8       +     .  ID=id-YP_002790881.1:216..290;Parent=cds-YP_00...
# 9       +     .  ID=id-YP_002790881.1:291..790;Parent=cds-YP_00...
# 10      +     .  ID=id-YP_002790881.1:791..1142;Parent=cds-YP_0...
# 11      +     .  ID=id-YP_002790881.1:1143..1368;Parent=cds-YP_...
# 12      +     .  ID=id-YP_002790881.1:1369..1498;Parent=cds-YP_...
# 13      +     .  ID=id-YP_002790881.1:1499..2115;Parent=cds-YP_...
# 14      +     .  ID=id-YP_002790881.1:2116..2242;Parent=cds-YP_...
# 15      +     .  ID=id-YP_002790881.1:2243..2265;Parent=cds-YP_...
# 16      +     .  ID=id-YP_002790881.1:2266..2516;Parent=cds-YP_...
# 17      +     .  ID=id-YP_002790881.1:2517..3419;Parent=cds-YP_...
# 18      +     .         ID=id-NC_012532.1:10367..10794;gbkey=3'UTR  , 'NC_001633.1.gff_df':          seqid  source feature_type  start   end score strand phase  \
# 0  NC_001633.1  RefSeq       region      1  4009     .      +     .
# 1  NC_001633.1  RefSeq         gene     61   600     .      +     .
# 2  NC_001633.1  RefSeq          CDS     61   600     .      +     0
# 3  NC_001633.1  RefSeq         gene     68  3144     .      +     .
# 4  NC_001633.1  RefSeq          CDS     68  1594     .      +     0
# 5  NC_001633.1  RefSeq          CDS   1594  3144     .      +     0
# 6  NC_001633.1  RefSeq         gene     68  2041     .      +     .
# 7  NC_001633.1  RefSeq          CDS     68  2041     .      +     0
# 8  NC_001633.1  RefSeq         gene   3163  3759     .      +     .
# 9  NC_001633.1  RefSeq          CDS   3163  3759     .      +     0
#
#                                           attributes
# 0  ID=NC_001633.1:1..4009;Dbxref=taxon:32625;coun...
# 1  ID=gene-MBVgp1;Dbxref=GeneID:1497109;Name=MBVg...
# 2  ID=cds-NP_042508.1;Parent=gene-MBVgp1;Dbxref=G...
# 3  ID=gene-MBVgp3;Dbxref=GeneID:1497107;Name=MBVg...
# 4  ID=cds-NP_042510.2;Parent=gene-MBVgp3;Dbxref=G...
# 5  ID=cds-NP_042510.2;Parent=gene-MBVgp3;Dbxref=G...
# 6  ID=gene-MBVgp2;Dbxref=GeneID:1497108;Name=MBVg...
# 7  ID=cds-NP_042509.1;Parent=gene-MBVgp2;Dbxref=G...
# 8  ID=gene-MBVgp4;Dbxref=GeneID:1497106;Name=MBVg...
# 9  ID=cds-NP_042511.1;Parent=gene-MBVgp4;Dbxref=G...  , 'NC_003555.1.gff_df':          seqid  source feature_type  start   end score strand phase  \
# 0  NC_003555.1  RefSeq       region      1  6277     .      +     .
# 1  NC_003555.1  RefSeq         gene    367  5978     .      +     .
# 2  NC_003555.1  RefSeq          CDS    367  2805     .      +     0
# 3  NC_003555.1  RefSeq          CDS   2805  5978     .      +     0
# 4  NC_003555.1  RefSeq         gene    367  3027     .      +     .
# 5  NC_003555.1  RefSeq          CDS    367  3027     .      +     0
#
#                                           attributes
# 0  ID=NC_003555.1:1..6277;Dbxref=taxon:29255;gbke...
# 1  ID=gene-GLVgp1;Dbxref=GeneID:940171;Name=GLVgp...
# 2  ID=cds-NP_620070.1;Parent=gene-GLVgp1;Dbxref=G...
# 3  ID=cds-NP_620070.1;Parent=gene-GLVgp1;Dbxref=G...
# 4  ID=gene-GLVgp2;Dbxref=GeneID:940170;Name=GLVgp...
# 5  ID=cds-NP_619551.1;Parent=gene-GLVgp2;Dbxref=G...  , 'NC_075114.1.gff_df':          seqid  source feature_type  start   end score strand phase  \
# 0  NC_075114.1  RefSeq       region      1  3248     .      +     .
# 1  NC_075114.1  RefSeq         gene   1374  1838     .      +     .
# 2  NC_075114.1  RefSeq          CDS   1374  1838     .      +     0
# 3  NC_075114.1  RefSeq         gene   1814  2488     .      +     .
# 4  NC_075114.1  RefSeq         gene   2343  4871     .      +     .
# 5  NC_075114.1  RefSeq          CDS   2343  4871     .      +     0
# 6  NC_075114.1  RefSeq         gene   2884  4083     .      +     .
# 7  NC_075114.1  RefSeq          CDS   2884  4083     .      +     0
#
#                                           attributes
# 0  ID=NC_075114.1:1..3248;Dbxref=taxon:10407;Is_c...
# 1  ID=gene-QJ942_gp3;Dbxref=GeneID:80519863;Name=...
# 2  ID=cds-YP_010782960.1;Parent=gene-QJ942_gp3;Db...
# 3  ID=gene-QJ942_gp4;Dbxref=GeneID:80519864;Name=...
# 4  ID=gene-QJ942_gp1;Dbxref=GeneID:80519866;Name=...
# 5  ID=cds-YP_010782958.1;Parent=gene-QJ942_gp1;Db...
# 6  ID=gene-QJ942_gp2;Dbxref=GeneID:80519865;Name=...
# 7  ID=cds-YP_010782959.1;Parent=gene-QJ942_gp2;Db...  , 'NC_001802.1.gff_df':           seqid  source                  feature_type  start   end score  \
# 0   NC_001802.1  RefSeq                        region      1  9181     .
# 1   NC_001802.1  RefSeq             biological_region      1    96     .
# 2   NC_001802.1  RefSeq         polyA_signal_sequence     73    78     .
# 3   NC_001802.1  RefSeq                five_prime_UTR     97   181     .
# 4   NC_001802.1  RefSeq           primer_binding_site    182   199     .
# 5   NC_001802.1  RefSeq                          gene    336  4642     .
# 6   NC_001802.1  RefSeq                           CDS    336  1637     .
# 7   NC_001802.1  RefSeq                           CDS   1637  4642     .
# 8   NC_001802.1  RefSeq  mature_protein_region_of_CDS   1632  1637     .
# 9   NC_001802.1  RefSeq  mature_protein_region_of_CDS   1637  1798     .
# 10  NC_001802.1  RefSeq  mature_protein_region_of_CDS   1655  4639     .
# 11  NC_001802.1  RefSeq  mature_protein_region_of_CDS   1799  2095     .
# 12  NC_001802.1  RefSeq  mature_protein_region_of_CDS   2096  3775     .
# 13  NC_001802.1  RefSeq  mature_protein_region_of_CDS   2096  3415     .
# 14  NC_001802.1  RefSeq  mature_protein_region_of_CDS   3776  4639     .
# 15  NC_001802.1  RefSeq                          gene    336  1838     .
# 16  NC_001802.1  RefSeq                           CDS    336  1838     .
# 17  NC_001802.1  RefSeq  mature_protein_region_of_CDS    336   731     .
# 18  NC_001802.1  RefSeq  mature_protein_region_of_CDS    732  1424     .
# 19  NC_001802.1  RefSeq  mature_protein_region_of_CDS   1425  1466     .
# 20  NC_001802.1  RefSeq  mature_protein_region_of_CDS   1467  1631     .
# 21  NC_001802.1  RefSeq  mature_protein_region_of_CDS   1632  1679     .
# 22  NC_001802.1  RefSeq  mature_protein_region_of_CDS   1680  1835     .
# 23  NC_001802.1  RefSeq                          gene   4587  5165     .
# 24  NC_001802.1  RefSeq                           CDS   4587  5165     .
# 25  NC_001802.1  RefSeq                          gene   5105  5396     .
# 26  NC_001802.1  RefSeq                           CDS   5105  5319     .
# 27  NC_001802.1  RefSeq                           CDS   5321  5396     .
# 28  NC_001802.1  RefSeq                          gene   5377  7970     .
# 29  NC_001802.1  RefSeq                           CDS   5377  5591     .
# 30  NC_001802.1  RefSeq                           CDS   7925  7970     .
# 31  NC_001802.1  RefSeq                          gene   5516  8199     .
# 32  NC_001802.1  RefSeq                           CDS   5516  5591     .
# 33  NC_001802.1  RefSeq                           CDS   7925  8199     .
# 34  NC_001802.1  RefSeq                          gene   5608  5856     .
# 35  NC_001802.1  RefSeq                           CDS   5608  5856     .
# 36  NC_001802.1  RefSeq                          gene   5771  8341     .
# 37  NC_001802.1  RefSeq                           CDS   5771  8341     .
# 38  NC_001802.1  RefSeq  signal_peptide_region_of_CDS   5771  5854     .
# 39  NC_001802.1  RefSeq  mature_protein_region_of_CDS   5855  7303     .
# 40  NC_001802.1  RefSeq  mature_protein_region_of_CDS   7304  8338     .
# 41  NC_001802.1  RefSeq                          gene   6919  7488     .
# 42  NC_001802.1  RefSeq                           CDS   6919  7488     .
# 43  NC_001802.1  RefSeq                          gene   8343  8963     .
# 44  NC_001802.1  RefSeq                           CDS   8343  8963     .
# 45  NC_001802.1  RefSeq               three_prime_UTR   8631  9085     .
# 46  NC_001802.1  RefSeq             biological_region   9086  9181     .
# 47  NC_001802.1  RefSeq         polyA_signal_sequence   9158  9163     .
#
#    strand phase                                         attributes
# 0       +     .  ID=NC_001802.1:1..9181;Dbxref=taxon:11676;gb-a...
# 1       +     .  ID=id-NC_001802.1:1..96;Name=R;Note=repeat%3B ...
# 2       +     .  ID=id-NC_001802.1:73..78;Note=both 5' and 3' p...
# 3       +     .              ID=id-NC_001802.1:97..181;gbkey=5'UTR
# 4       +     .       ID=id-NC_001802.1:182..199;gbkey=primer_bind
# 5       +     .  ID=gene-HIV1gp1;Dbxref=GeneID:155348;Name=gag-...
# 6       +     0  ID=cds-NP_057849.4;Parent=gene-HIV1gp1;Dbxref=...
# 7       +     0  ID=cds-NP_057849.4;Parent=gene-HIV1gp1;Dbxref=...
# 8       +     .  ID=id-NP_057849.4:433..488;Note=the Glu-Asp-Le...
# 9       +     .  ID=id-NP_057849.4:433..488;Note=the Glu-Asp-Le...
# 10      +     .  ID=id-NP_057849.4:441..1435;Note=unprocessed P...
# 11      +     .  ID=id-NP_057849.4:489..587;Note=The proteinase...
# 12      +     .  ID=id-NP_057849.4:588..1147;Note=transcribes s...
# 13      +     .  ID=id-NP_057849.4:588..1027;Note=HIV-1 reverse...
# 14      +     .  ID=id-NP_057849.4:1148..1435;Note=mediates int...
# 15      +     .  ID=gene-HIV1gp2;Dbxref=GeneID:155030;Name=gag;...
# 16      +     0  ID=cds-NP_057850.1;Parent=gene-HIV1gp2;Dbxref=...
# 17      +     .  ID=id-NP_057850.1:1..132;Note=viral structural...
# 18      +     .  ID=id-NP_057850.1:133..363;Note=viral structur...
# 19      +     .  ID=id-NP_057850.1:364..377;Note=Processing of ...
# 20      +     .  ID=id-NP_057850.1:378..432;Note=viral structur...
# 21      +     .  ID=id-NP_057850.1:433..448;Note=important for ...
# 22      +     .  ID=id-NP_057850.1:449..500;Note=important for ...
# 23      +     .  ID=gene-HIV1gp3;Dbxref=GeneID:155459;Name=vif;...
# 24      +     0  ID=cds-NP_057851.1;Parent=gene-HIV1gp3;Dbxref=...
# 25      +     .  ID=gene-HIV1gp4;Dbxref=GeneID:155807;Name=vpr;...
# 26      +     0  ID=cds-NP_057852.2;Parent=gene-HIV1gp4;Dbxref=...
# 27      +     1  ID=cds-NP_057852.2;Parent=gene-HIV1gp4;Dbxref=...
# 28      +     .  ID=gene-HIV1gp5;Dbxref=GeneID:155871;Name=tat;...
# 29      +     0  ID=cds-NP_057853.1;Parent=gene-HIV1gp5;Dbxref=...
# 30      +     1  ID=cds-NP_057853.1;Parent=gene-HIV1gp5;Dbxref=...
# 31      +     .  ID=gene-HIV1gp6;Dbxref=GeneID:155908;Name=rev;...
# 32      +     0  ID=cds-NP_057854.1;Parent=gene-HIV1gp6;Dbxref=...
# 33      +     2  ID=cds-NP_057854.1;Parent=gene-HIV1gp6;Dbxref=...
# 34      +     .  ID=gene-HIV1gp7;Dbxref=GeneID:155945;Name=vpu;...
# 35      +     0  ID=cds-NP_057855.1;Parent=gene-HIV1gp7;Dbxref=...
# 36      +     .  ID=gene-HIV1gp8;Dbxref=GeneID:155971;Name=env;...
# 37      +     0  ID=cds-NP_057856.1;Parent=gene-HIV1gp8;Dbxref=...
# 38      +     .  ID=id-NP_057856.1:1..28;Parent=cds-NP_057856.1...
# 39      +     .  ID=id-NP_057856.1:29..511;Note=mediates bindin...
# 40      +     .  ID=id-NP_057856.1:512..856;Note=cooperates wit...
# 41      -     .  ID=gene-HIV1gp10;Dbxref=GeneID:19424028;Name=a...
# 42      -     0  ID=cds-YP_009028572.1;Parent=gene-HIV1gp10;Dbx...
# 43      +     .  ID=gene-HIV1gp9;Dbxref=GeneID:156110;Name=nef;...
# 44      +     0  ID=cds-NP_057857.2;Parent=gene-HIV1gp9;Dbxref=...
# 45      +     .           ID=id-NC_001802.1:8631..9085;gbkey=3'UTR
# 46      +     .  ID=id-NC_001802.1:9086..9181;Name=R;Note=repea...
# 47      +     .  ID=id-NC_001802.1:9158..9163;Note=both 5' and ...  , 'NC_001498.1.gff_df':           seqid  source feature_type  start    end score strand phase  \
# 0   NC_001498.1  RefSeq       region      1  15894     .      +     .
# 1   NC_001498.1  RefSeq         gene     56   1744     .      +     .
# 2   NC_001498.1  RefSeq         mRNA     56   1744     .      +     .
# 3   NC_001498.1  RefSeq         exon     56   1744     .      +     .
# 4   NC_001498.1  RefSeq          CDS    108   1685     .      +     0
# 5   NC_001498.1  RefSeq         gene   1748   3402     .      +     .
# 6   NC_001498.1  RefSeq          CDS   1807   2499     .      +     0
# 7   NC_001498.1  RefSeq          CDS   2499   2705     .      +     0
# 8   NC_001498.1  RefSeq         mRNA   1748   3402     .      +     .
# 9   NC_001498.1  RefSeq         exon   1748   3402     .      +     .
# 10  NC_001498.1  RefSeq          CDS   1807   3330     .      +     0
# 11  NC_001498.1  RefSeq          CDS   1829   2389     .      +     0
# 12  NC_001498.1  RefSeq         gene   3406   4872     .      +     .
# 13  NC_001498.1  RefSeq         mRNA   3406   4872     .      +     .
# 14  NC_001498.1  RefSeq         exon   3406   4872     .      +     .
# 15  NC_001498.1  RefSeq          CDS   3438   4445     .      +     0
# 16  NC_001498.1  RefSeq         gene   4876   7247     .      +     .
# 17  NC_001498.1  RefSeq         mRNA   4876   7247     .      +     .
# 18  NC_001498.1  RefSeq         exon   4876   7247     .      +     .
# 19  NC_001498.1  RefSeq          CDS   5458   7110     .      +     0
# 20  NC_001498.1  RefSeq         gene   7251   9208     .      +     .
# 21  NC_001498.1  RefSeq         mRNA   7251   9208     .      +     .
# 22  NC_001498.1  RefSeq         exon   7251   9208     .      +     .
# 23  NC_001498.1  RefSeq          CDS   7271   9124     .      +     0
# 24  NC_001498.1  RefSeq         gene   9212  15854     .      +     .
# 25  NC_001498.1  RefSeq         mRNA   9212  15854     .      +     .
# 26  NC_001498.1  RefSeq         exon   9212  15854     .      +     .
# 27  NC_001498.1  RefSeq          CDS   9234  15785     .      +     0
#
#                                            attributes
# 0   ID=NC_001498.1:1..15894;Dbxref=taxon:11234;gbk...
# 1   ID=gene-MeVgp1;Dbxref=GeneID:1489804;Name=N;gb...
# 2   ID=rna-MeVgp1;Parent=gene-MeVgp1;Dbxref=GeneID...
# 3   ID=exon-MeVgp1-1;Parent=rna-MeVgp1;Dbxref=Gene...
# 4   ID=cds-NP_056918.1;Parent=rna-MeVgp1;Dbxref=Ge...
# 5   ID=gene-MeVgp2;Dbxref=GeneID:1489805;Name=P/V/...
# 6   ID=cds-YP_003873249.2;Parent=gene-MeVgp2;Dbxre...
# 7   ID=cds-YP_003873249.2;Parent=gene-MeVgp2;Dbxre...
# 8   ID=rna-MeVgp2;Parent=gene-MeVgp2;Dbxref=GeneID...
# 9   ID=exon-MeVgp2-1;Parent=rna-MeVgp2;Dbxref=Gene...
# 10  ID=cds-NP_056919.1;Parent=rna-MeVgp2;Dbxref=Ge...
# 11  ID=cds-NP_056920.1;Parent=rna-MeVgp2;Dbxref=Ge...
# 12  ID=gene-MeVgp3;Dbxref=GeneID:1489803;Name=M;gb...
# 13  ID=rna-MeVgp3;Parent=gene-MeVgp3;Dbxref=GeneID...
# 14  ID=exon-MeVgp3-1;Parent=rna-MeVgp3;Dbxref=Gene...
# 15  ID=cds-NP_056921.1;Parent=rna-MeVgp3;Dbxref=Ge...
# 16  ID=gene-MeVgp4;Dbxref=GeneID:1489800;Name=F;gb...
# 17  ID=rna-MeVgp4;Parent=gene-MeVgp4;Dbxref=GeneID...
# 18  ID=exon-MeVgp4-1;Parent=rna-MeVgp4;Dbxref=Gene...
# 19  ID=cds-NP_056922.1;Parent=rna-MeVgp4;Dbxref=Ge...
# 20  ID=gene-MeVgp5;Dbxref=GeneID:1489801;Name=H;gb...
# 21  ID=rna-MeVgp5;Parent=gene-MeVgp5;Dbxref=GeneID...
# 22  ID=exon-MeVgp5-1;Parent=rna-MeVgp5;Dbxref=Gene...
# 23  ID=cds-NP_056923.1;Parent=rna-MeVgp5;Dbxref=Ge...
# 24  ID=gene-MeVgp6;Dbxref=GeneID:1489802;Name=L;gb...
# 25  ID=rna-MeVgp6;Parent=gene-MeVgp6;Dbxref=GeneID...
# 26  ID=exon-MeVgp6-1;Parent=rna-MeVgp6;Dbxref=Gene...
# 27  ID=cds-NP_056924.1;Parent=rna-MeVgp6;Dbxref=Ge...  , 'NC_055061.1.gff_df':            seqid  source         feature_type  start    end score strand  \
# 0    NC_055061.1  RefSeq               region      1  17253     .      +
# 1    NC_055061.1  RefSeq                 gene     89    371     .      -
# 2    NC_055061.1  RefSeq                  CDS     90    359     .      -
# 3    NC_055061.1  RefSeq                 gene    355    575     .      -
# 4    NC_055061.1  RefSeq                  CDS    356    559     .      -
# ..           ...     ...                  ...    ...    ...   ...    ...
# 101  NC_055061.1  RefSeq                  CDS  16602  16784     .      +
# 102  NC_055061.1  RefSeq  ribosome_entry_site  16589  16591     .      +
# 103  NC_055061.1  RefSeq                 gene  16863  17161     .      +
# 104  NC_055061.1  RefSeq                  CDS  16874  17161     .      +
# 105  NC_055061.1  RefSeq  ribosome_entry_site  16863  16868     .      +
#
#     phase                                         attributes
# 0       .  ID=NC_055061.1:1..17253;Dbxref=taxon:1975614;c...
# 1       .  ID=gene-KMD62_gp01;Dbxref=GeneID:65073169;Name...
# 2       0  ID=cds-YP_010084097.1;Parent=gene-KMD62_gp01;D...
# 3       .  ID=gene-KMD62_gp02;Dbxref=GeneID:65073135;Name...
# 4       0  ID=cds-YP_010084098.1;Parent=gene-KMD62_gp02;D...
# ..    ...                                                ...
# 101     0  ID=cds-YP_010084130.1;Parent=gene-KMD62_gp34;D...
# 102     .  ID=id-KMD62_gp34;Parent=gene-KMD62_gp34;Dbxref...
# 103     .  ID=gene-KMD62_gp35;Dbxref=GeneID:65073168;Name...
# 104     0  ID=cds-YP_010084131.1;Parent=gene-KMD62_gp35;D...
# 105     .  ID=id-KMD62_gp35;Parent=gene-KMD62_gp35;Dbxref...
#
# [106 rows x 9 columns], 'NC_007409.1.gff_df':            seqid  source feature_type  start    end score strand phase  \
# 0    NC_007409.1  RefSeq       region      1  62730     .      +     .
# 1    NC_007409.1  RefSeq         gene     14    178     .      +     .
# 2    NC_007409.1  RefSeq          CDS     14    178     .      +     0
# 3    NC_007409.1  RefSeq         gene    152    973     .      -     .
# 4    NC_007409.1  RefSeq          CDS    152    973     .      -     0
# ..           ...     ...          ...    ...    ...   ...    ...   ...
# 140  NC_007409.1  RefSeq          CDS  56849  57829     .      -     0
# 141  NC_007409.1  RefSeq         gene  57892  61896     .      -     .
# 142  NC_007409.1  RefSeq          CDS  57892  61896     .      -     0
# 143  NC_007409.1  RefSeq         gene  61995  62720     .      +     .
# 144  NC_007409.1  RefSeq          CDS  61995  62720     .      +     0
#
#                                             attributes
# 0    ID=NC_007409.1:1..62730;Dbxref=taxon:315953;Is...
# 1    ID=gene-ATV_gp01;Dbxref=GeneID:4484219;Name=AT...
# 2    ID=cds-YP_319832.1;Parent=gene-ATV_gp01;Dbxref...
# 3    ID=gene-ATV_gp02;Dbxref=GeneID:4484280;Name=AT...
# 4    ID=cds-YP_319833.1;Parent=gene-ATV_gp02;Dbxref...
# ..                                                 ...
# 140  ID=cds-YP_319901.1;Parent=gene-ATV_gp70;Dbxref...
# 141  ID=gene-ATV_gp71;Dbxref=GeneID:4484271;Name=AT...
# 142  ID=cds-YP_319902.1;Parent=gene-ATV_gp71;Dbxref...
# 143  ID=gene-ATV_gp72;Dbxref=GeneID:4484279;Name=AT...
# 144  ID=cds-YP_319903.1;Parent=gene-ATV_gp72;Dbxref...
#
# [145 rows x 9 columns], 'NC_001538.1.gff_df':           seqid  source           feature_type  start   end score strand  \
# 0   NC_001538.1  RefSeq                 region      1  5153     .      +
# 1   NC_001538.1  RefSeq  origin_of_replication     97   119     .      +
# 2   NC_001538.1  RefSeq                   gene    388   588     .      +
# 3   NC_001538.1  RefSeq                    CDS    388   588     .      +
# 4   NC_001538.1  RefSeq                   gene    624  1679     .      +
# 5   NC_001538.1  RefSeq                    CDS    624  1679     .      +
# 6   NC_001538.1  RefSeq                   gene    981  1679     .      +
# 7   NC_001538.1  RefSeq                    CDS    981  1679     .      +
# 8   NC_001538.1  RefSeq                   gene   1564  2652     .      +
# 9   NC_001538.1  RefSeq                    CDS   1564  2652     .      +
# 10  NC_001538.1  RefSeq                   gene   2722  5153     .      -
# 11  NC_001538.1  RefSeq                    CDS   4911  5153     .      -
# 12  NC_001538.1  RefSeq                    CDS   2722  4566     .      -
# 13  NC_001538.1  RefSeq                 intron   4567  4910     .      -
# 14  NC_001538.1  RefSeq                   gene   4635  5153     .      -
# 15  NC_001538.1  RefSeq                    CDS   4635  5153     .      -
#
#    phase                                         attributes
# 0      .  ID=NC_001538.1:1..5153;Dbxref=taxon:1891762;Is...
# 1      .  ID=id-NC_001538.1:97..119;Note=origin of repli...
# 2      .  ID=gene-BKPyVgp1;Dbxref=GeneID:29031013;Name=B...
# 3      0  ID=cds-YP_717936.1;Parent=gene-BKPyVgp1;Dbxref...
# 4      .  ID=gene-BKPyVgp2;Dbxref=GeneID:29031010;Name=B...
# 5      0  ID=cds-YP_717937.1;Parent=gene-BKPyVgp2;Dbxref...
# 6      .  ID=gene-BKPyVgp3;Dbxref=GeneID:29031011;Name=B...
# 7      0  ID=cds-YP_717938.1;Parent=gene-BKPyVgp3;Dbxref...
# 8      .  ID=gene-BKPyVgp4;Dbxref=GeneID:29031008;Name=B...
# 9      0  ID=cds-YP_717939.1;Parent=gene-BKPyVgp4;Dbxref...
# 10     .  ID=gene-BKPyVgp5;Dbxref=GeneID:29031009;Name=B...
# 11     0  ID=cds-YP_717940.1;Parent=gene-BKPyVgp5;Dbxref...
# 12     0  ID=cds-YP_717940.1;Parent=gene-BKPyVgp5;Dbxref...
# 13     .  ID=id-BKPyVgp5;Parent=gene-BKPyVgp5;Dbxref=Gen...
# 14     .  ID=gene-BKPyVgp6;Dbxref=GeneID:29031012;Name=B...
# 15     0  ID=cds-YP_717941.1;Parent=gene-BKPyVgp6;Dbxref...  , 'NC_018519.1.gff_df':           seqid  source                  feature_type  start    end score  \
# 0   NC_018519.1  RefSeq                        region      1  17798     .
# 1   NC_018519.1  RefSeq                          gene    116  10847     .
# 2   NC_018519.1  RefSeq                           CDS    116   9265     .
# 3   NC_018519.1  RefSeq                           CDS   9267  10847     .
# 4   NC_018519.1  RefSeq  mature_protein_region_of_CDS   9267  10844     .
# 5   NC_018519.1  RefSeq                          gene    116   9268     .
# 6   NC_018519.1  RefSeq                           CDS    116   9268     .
# 7   NC_018519.1  RefSeq                          gene  10962  11135     .
# 8   NC_018519.1  RefSeq                           CDS  10962  11135     .
# 9   NC_018519.1  RefSeq                          gene  11132  12952     .
# 10  NC_018519.1  RefSeq                           CDS  11132  12952     .
# 11  NC_018519.1  RefSeq                          gene  12989  14530     .
# 12  NC_018519.1  RefSeq                           CDS  12989  14530     .
# 13  NC_018519.1  RefSeq                          gene  14674  15321     .
# 14  NC_018519.1  RefSeq                           CDS  14674  15321     .
# 15  NC_018519.1  RefSeq                          gene  15380  15997     .
# 16  NC_018519.1  RefSeq                           CDS  15380  15997     .
# 17  NC_018519.1  RefSeq                          gene  16424  17170     .
# 18  NC_018519.1  RefSeq                           CDS  16424  17170     .
# 19  NC_018519.1  RefSeq                          gene  17161  17337     .
# 20  NC_018519.1  RefSeq                           CDS  17161  17337     .
# 21  NC_018519.1  RefSeq                          gene  17346  17621     .
# 22  NC_018519.1  RefSeq                           CDS  17346  17621     .
#
#    strand phase                                         attributes
# 0       +     .  ID=NC_018519.1:1..17798;Dbxref=taxon:1206566;c...
# 1       +     .  ID=gene-C194_gp01;Dbxref=GeneID:13520503;Name=...
# 2       +     0  ID=cds-YP_006628167.1;Parent=gene-C194_gp01;Db...
# 3       +     0  ID=cds-YP_006628167.1;Parent=gene-C194_gp01;Db...
# 4       +     .  ID=id-YP_006628167.1:3051..3576;Note=ORF1b;Par...
# 5       +     .  ID=gene-C194_gp02;Dbxref=GeneID:13520494;Name=...
# 6       +     0  ID=cds-YP_006628168.1;Parent=gene-C194_gp02;Db...
# 7       +     .  ID=gene-C194_gp03;Dbxref=GeneID:13520495;Name=...
# 8       +     0  ID=cds-YP_006628169.1;Parent=gene-C194_gp03;Db...
# 9       +     .  ID=gene-C194_gp04;Dbxref=GeneID:13520496;Name=...
# 10      +     0  ID=cds-YP_006628170.1;Parent=gene-C194_gp04;Db...
# 11      +     .  ID=gene-C194_gp05;Dbxref=GeneID:13520497;Name=...
# 12      +     0  ID=cds-YP_006628171.1;Parent=gene-C194_gp05;Db...
# 13      +     .  ID=gene-C194_gp06;Dbxref=GeneID:13520498;Name=...
# 14      +     0  ID=cds-YP_006628172.1;Parent=gene-C194_gp06;Db...
# 15      +     .  ID=gene-C194_gp07;Dbxref=GeneID:13520499;Name=...
# 16      +     0  ID=cds-YP_006628173.1;Parent=gene-C194_gp07;Db...
# 17      +     .  ID=gene-C194_gp08;Dbxref=GeneID:13520500;Name=...
# 18      +     0  ID=cds-YP_006628174.1;Parent=gene-C194_gp08;Db...
# 19      +     .  ID=gene-C194_gp09;Dbxref=GeneID:13520501;Name=...
# 20      +     0  ID=cds-YP_006628175.1;Parent=gene-C194_gp09;Db...
# 21      +     .  ID=gene-C194_gp10;Dbxref=GeneID:13520502;Name=...
# 22      +     0  ID=cds-YP_006628176.1;Parent=gene-C194_gp10;Db...  , 'NC_014821.1.gff_df':           seqid  source     feature_type  start   end score strand phase  \
# 0   NC_014821.1  RefSeq           region      1  9311     .      +     .
# 1   NC_014821.1  RefSeq   five_prime_UTR      1    60     .      +     .
# 2   NC_014821.1  RefSeq             gene     61  6615     .      +     .
# 3   NC_014821.1  RefSeq              CDS     61  6615     .      +     0
# 4   NC_014821.1  RefSeq             gene   6674  7345     .      +     .
# 5   NC_014821.1  RefSeq              CDS   6674  7345     .      +     0
# 6   NC_014821.1  RefSeq             gene   7347  7706     .      +     .
# 7   NC_014821.1  RefSeq              CDS   7347  7706     .      +     0
# 8   NC_014821.1  RefSeq             gene   7615  7827     .      +     .
# 9   NC_014821.1  RefSeq              CDS   7615  7827     .      +     0
# 10  NC_014821.1  RefSeq             gene   7913  9178     .      +     .
# 11  NC_014821.1  RefSeq              CDS   7913  9178     .      +     0
# 12  NC_014821.1  RefSeq  three_prime_UTR   9173  9311     .      +     .
#
#                                            attributes
# 0   ID=NC_014821.1:1..9311;Dbxref=taxon:75387;coun...
# 1                 ID=id-NC_014821.1:1..60;gbkey=5'UTR
# 2   ID=gene-ApLV_gp1;Dbxref=GeneID:10051549;Name=R...
# 3   ID=cds-YP_004089619.1;Parent=gene-ApLV_gp1;Dbx...
# 4   ID=gene-ApLV_gp2;Dbxref=GeneID:10051545;Name=t...
# 5   ID=cds-YP_004089620.1;Parent=gene-ApLV_gp2;Dbx...
# 6   ID=gene-ApLV_gp3;Dbxref=GeneID:10051546;Name=t...
# 7   ID=cds-YP_004089621.1;Parent=gene-ApLV_gp3;Dbx...
# 8   ID=gene-ApLV_gp4;Dbxref=GeneID:10051547;Name=t...
# 9   ID=cds-YP_004089622.1;Parent=gene-ApLV_gp4;Dbx...
# 10  ID=gene-ApLV_gp5;Dbxref=GeneID:10051548;Name=c...
# 11  ID=cds-YP_004089623.1;Parent=gene-ApLV_gp5;Dbx...
# 12           ID=id-NC_014821.1:9173..9311;gbkey=3'UTR  , 'NC_076918.1.gff_df':          seqid  source feature_type  start   end score strand phase  \
# 0  NC_076918.1  RefSeq       region      1  6632     .      +     .
# 1  NC_076918.1  RefSeq         gene     13  4701     .      +     .
# 2  NC_076918.1  RefSeq          CDS     13  4701     .      +     0
# 3  NC_076918.1  RefSeq         gene   4732  6555     .      +     .
# 4  NC_076918.1  RefSeq          CDS   4732  6555     .      +     0
# 5  NC_076918.1  RefSeq         gene   4739  5179     .      +     .
# 6  NC_076918.1  RefSeq          CDS   4739  5179     .      +     0
#
#                                           attributes
# 0  ID=NC_076918.1:1..6632;Dbxref=taxon:1216472;co...
# 1  ID=gene-QKS98_gp1;Dbxref=GeneID:80539579;Name=...
# 2  ID=cds-YP_010800917.1;Parent=gene-QKS98_gp1;Db...
# 3  ID=gene-QKS98_gp2;Dbxref=GeneID:80539577;Name=...
# 4  ID=cds-YP_010800918.1;Parent=gene-QKS98_gp2;Db...
# 5  ID=gene-QKS98_gp3;Dbxref=GeneID:80539578;Name=...
# 6  ID=cds-YP_010800919.1;Parent=gene-QKS98_gp3;Db...  , 'NC_017970.1.gff_df':           seqid  source                  feature_type  start    end score  \
# 0   NC_017970.1  RefSeq                        region      1  10731     .
# 1   NC_017970.1  RefSeq                          gene    118  10518     .
# 2   NC_017970.1  RefSeq                           CDS    118  10518     .
# 3   NC_017970.1  RefSeq  mature_protein_region_of_CDS    118   1971     .
# 4   NC_017970.1  RefSeq  mature_protein_region_of_CDS   1972   3345     .
# 5   NC_017970.1  RefSeq  mature_protein_region_of_CDS   3346   4401     .
# 6   NC_017970.1  RefSeq  mature_protein_region_of_CDS   4402   4557     .
# 7   NC_017970.1  RefSeq  mature_protein_region_of_CDS   4558   6486     .
# 8   NC_017970.1  RefSeq  mature_protein_region_of_CDS   6487   6645     .
# 9   NC_017970.1  RefSeq  mature_protein_region_of_CDS   6646   7227     .
# 10  NC_017970.1  RefSeq  mature_protein_region_of_CDS   7228   7956     .
# 11  NC_017970.1  RefSeq  mature_protein_region_of_CDS   7957   9519     .
# 12  NC_017970.1  RefSeq  mature_protein_region_of_CDS   9520  10515     .
# 13  NC_017970.1  RefSeq                          gene   3816   4007     .
# 14  NC_017970.1  RefSeq                           CDS   3816   4007     .
#
#    strand phase                                         attributes
# 0       +     .  ID=NC_017970.1:1..10731;Dbxref=taxon:453050;co...
# 1       +     .  ID=gene-A329_gp1;Dbxref=GeneID:12978759;Name=A...
# 2       +     0  ID=cds-YP_006382460.1;Parent=gene-A329_gp1;Dbx...
# 3       +     .  ID=id-YP_006382460.1:1..618;Parent=cds-YP_0063...
# 4       +     .  ID=id-YP_006382460.1:619..1076;Parent=cds-YP_0...
# 5       +     .  ID=id-YP_006382460.1:1077..1428;Parent=cds-YP_...
# 6       +     .  ID=id-YP_006382460.1:1429..1480;Parent=cds-YP_...
# 7       +     .  ID=id-YP_006382460.1:1481..2123;Parent=cds-YP_...
# 8       +     .  ID=id-YP_006382460.1:2124..2176;Parent=cds-YP_...
# 9       +     .  ID=id-YP_006382460.1:2177..2370;Parent=cds-YP_...
# 10      +     .  ID=id-YP_006382460.1:2371..2613;Parent=cds-YP_...
# 11      +     .  ID=id-YP_006382460.1:2614..3134;Parent=cds-YP_...
# 12      +     .  ID=id-YP_006382460.1:3135..3466;Parent=cds-YP_...
# 13      +     .  ID=gene-A329_gp2;Dbxref=GeneID:13036848;Name=A...
# 14      +     0  ID=cds-YP_006438187.1;Parent=gene-A329_gp2;Dbx...  }

# %% [markdown]
# # Number of Chromosomes

# %% [markdown]
# # Number of CDS

# %%
import pandas as pd

def no_cds(gff_dict):
    gff_keys = [str(accession) + ".gff" +"_df" for accession in accession_ids]
    cds_list = []
    for keys in gff_keys:
        cds=0
        df1 = gff_dict[keys]
        for i in df1['feature_type']:
            if i == "CDS":
                cds+=1
            else:
                continue
        cds_list.append(cds)
    return cds_list

cds_list = no_cds(gff_dict)

data['Number_of_CDS'] = cds_list
print(data)
# Out:
#    Accession ID  Genome_size  GC_percentage  Number_of_CDS
# 0   NC_075037.1      1016844      24.715492            976
# 1   NC_021858.1      1908524      63.663962           1189
# 2   NC_023423.1       610033      35.798391            468
# 3   NC_037057.1       181035      52.726268            227
# 4   NC_044945.1       191058      38.252258            168
# 5   NC_037656.1       127879      31.279569            132
# 6   NC_044939.1       199721      45.845454            194
# 7   NC_001824.1       102653      29.070753            110
# 8   NC_006273.2       235646      57.482410            188
# 9   NC_002331.1       178733      40.678554            181
# 10  NC_001460.1        34125      46.523077             42
# 11  NC_010537.1        41172      34.644904             73
# 12  NC_076691.1        18371      51.075064              1
# 13  NC_055060.1        18266      54.620607             36
# 14  NC_004718.3        29751      40.761655             16
# 15  NC_004162.2        11826      50.042280              2
# 16  NC_012532.1        10794      50.935705              1
# 17  NC_001633.1         4009      46.270890              5
# 18  NC_003555.1         6277      50.039828              3
# 19  NC_075114.1         3248      48.275862              3
# 20  NC_001802.1         9181      42.119595             14
# 21  NC_001498.1        15894      47.426702              9
# 22  NC_055061.1        17253      54.471686             35
# 23  NC_007409.1        62730      41.225889             72
# 24  NC_001538.1         5153      39.530371              7
# 25  NC_076691.1        18371      51.075064              1
# 26  NC_018519.1        17798      45.595011             11
# 27  NC_014821.1         9311      42.433681              5
# 28  NC_076918.1         6632      52.080820              3
# 29  NC_017970.1        10731      40.928152              2

# %% [markdown]
# # Number of non coding genes

# %% [markdown]
# # Length of genes (without considering overlap)

# %%
import pandas as pd

def length_gene(gff_dict):
    gene_length = []
    gff_keys = [str(accession) + ".gff" +"_df" for accession in accession_ids]
    for keys in gff_keys:
        
        data=gff_dict[keys]
        filtered_df = data[data['feature_type']=='gene'].copy()
        filtered_df['sub'] = filtered_df['end']-filtered_df['start'] + 1
        res_li=filtered_df['sub'].tolist()
        
        summation= sum(res_li)
        gene_length.append(summation)
    return gene_length

length_ = length_gene(gff_dict)
data['length_of_gene']= length_
print(data)
# Out:
#    Accession ID  Genome_size  GC_percentage  Number_of_CDS  length_of_gene
# 0   NC_075037.1      1016844      24.715492            976          922313
# 1   NC_021858.1      1908524      63.663962           1189         1901268
# 2   NC_023423.1       610033      35.798391            468          421333
# 3   NC_037057.1       181035      52.726268            227          175056
# 4   NC_044945.1       191058      38.252258            168          168603
# 5   NC_037656.1       127879      31.279569            132          121413
# 6   NC_044939.1       199721      45.845454            194          173733
# 7   NC_001824.1       102653      29.070753            110           95058
# 8   NC_006273.2       235646      57.482410            188          250752
# 9   NC_002331.1       178733      40.678554            181          157953
# 10  NC_001460.1        34125      46.523077             42          123802
# 11  NC_010537.1        41172      34.644904             73           37425
# 12  NC_076691.1        18371      51.075064              1           16035
# 13  NC_055060.1        18266      54.620607             36           16849
# 14  NC_004718.3        29751      40.761655             16           29974
# 15  NC_004162.2        11826      50.042280              2           11172
# 16  NC_012532.1        10794      50.935705              1           10260
# 17  NC_001633.1         4009      46.270890              5            6188
# 18  NC_003555.1         6277      50.039828              3            8273
# 19  NC_075114.1         3248      48.275862              3            4869
# 20  NC_001802.1         9181      42.119595             14           15970
# 21  NC_001498.1        15894      47.426702              9           15784
# 22  NC_055061.1        17253      54.471686             35           17019
# 23  NC_007409.1        62730      41.225889             72           58008
# 24  NC_001538.1         5153      39.530371              7            5996
# 25  NC_076691.1        18371      51.075064              1           16035
# 26  NC_018519.1        17798      45.595011             11           25888
# 27  NC_014821.1         9311      42.433681              5            9066
# 28  NC_076918.1         6632      52.080820              3            6954
# 29  NC_017970.1        10731      40.928152              2           10593

# %% [markdown]
# # Fraction of genome covered by CDS

# %% [markdown]
# # Number of exons or introns per gene

# %% [markdown]
# # Size of exons

# %% [markdown]
# # Size of introns

# %% [markdown]
# # Size of 5' UTR

# %% [markdown]
# # Size of 3' UTR
